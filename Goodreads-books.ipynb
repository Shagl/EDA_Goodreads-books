# %% [markdown]
# Dataset : https://www.kaggle.com/jealousleopard/goodreadsbooks

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime
import calendar
import plotly.io as pio
pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'plotly_mimetype+notebook'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery', 'sphinx_gallery_png']

# %% [markdown]
# IMPORT THE DATASET

# %%
books_data= pd.read_csv('books.csv', error_bad_lines=False)
books_data.head(5)
# Out:
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# ...

# %% [markdown]
# DATA EXPLORATION

# %%
books_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %%
books_data.shape
# Out:
# (11123, 12)

# %% [markdown]
# MISSING VALUES

# %%
books_data.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %% [markdown]
# DATA PREPROSSING

# %%
books_data['publish_year']= books_data['publication_date'].str.split('/').apply(lambda x:x[2]).astype(int)
books_data['publish_month']= books_data['publication_date'].str.split('/').apply(lambda x:x[0]).astype(int).apply(lambda x: calendar.month_abbr[x])
books_data.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# ...

# %%
books_data['average_rating']= round(books_data['average_rating'],1)
books_data.head(5)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré             4.6  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré             4.5  0439358078  9780439358071
# 2                J.K. Rowling             4.4  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré             4.6  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré             4.8  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# ...

# %%
books_data.rename(columns={'  num_pages': 'num_pages'}, inplace= True)
books_data.drop(columns=["isbn", "isbn13","bookID", "publication_date"],inplace=True)

books_data.head(5)
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating language_code  num_pages  \
# 0  J.K. Rowling/Mary GrandPré             4.6           eng        652
# 1  J.K. Rowling/Mary GrandPré             4.5           eng        870
# 2                J.K. Rowling             4.4           eng        352
# 3  J.K. Rowling/Mary GrandPré             4.6           eng        435
# 4  J.K. Rowling/Mary GrandPré             4.8           eng       2690
#
#    ratings_count  text_reviews_count        publisher  publish_year  \
# 0        2095690               27591  Scholastic Inc.          2006
# 1        2153167               29221  Scholastic Inc.          2004
# ...

# %%
#books_data.drop(columns=["isbn", "isbn13","bookID", "publication_date"],inplace=True)
#books_data

# %% [markdown]
# DATA VISUALIZATION

# %%
lowratings_books= books_data.loc[(books_data['average_rating'] <= 3.0)]
lowratings_books.head()
# Out:
#                                                  title  \
# 96                           Dinner with Anna Karenina
# 265  Out to Eat London 2002 (Lonely Planet Out to Eat)
# 375                     Juiced Official Strategy Guide
# 507  Cliffs Notes on Aristophanes' Lysistrata  The ...
# 525  American Government: Continuity and Change  Al...
#
#                              authors  average_rating language_code  num_pages  \
# 96                  Gloria Goldreich             3.0           eng        360
# 265         Lonely Planet/Mark Honan             0.0           eng        295
# 375                       Doug Walsh             0.0           eng        112
# 507                 W. John Campbell             2.8           eng         80
# 525  Karen  O'Connor/Larry J. Sabato             2.8           eng        664
#
#      ratings_count  text_reviews_count                 publisher  \
# 96             411                  65                Mira Books
# ...

# %%
lowratings_books_fig= px.scatter(lowratings_books, x='ratings_count', y='average_rating' ,hover_data= ['title', 'authors','num_pages','text_reviews_count'], size='num_pages',size_max=25,color="average_rating" )
lowratings_books_fig.show(renderer="svg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-e8c5a81b9ec3> in <module>
#       1 lowratings_books_fig= px.scatter(lowratings_books, x='ratings_count', y='average_rating' ,hover_data= ['title', 'authors','num_pages','text_reviews_count'], size='num_pages',size_max=25,color="average_rating" )
# ----> 2 lowratings_books_fig.show(renderer="svg")
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in show(self, *args, **kwargs)
#    2853         import plotly.io as pio
#    2854
# -> 2855         return pio.show(self, *args, **kwargs)
#    2856
#    2857     def to_json(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\plotly\io\_renderers.py in show(fig, renderer, validate, **kwargs)
#     375
#     376     # Mimetype renderers
# --> 377     bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
# ...

# %%
highestrated_books= books_data.loc[(books_data['average_rating'] > 4.0)]
highestrated_books.head()

# %%
highestrated_books_fig = px.scatter(highestrated_books, x='ratings_count', y='average_rating' ,hover_data= ['title', 'authors','num_pages','text_reviews_count'],color="average_rating" )
highestrated_books_fig.show(renderer="svg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-7f0e9ce78a7b> in <module>
#       1 highestrated_books_fig = px.scatter(highestrated_books, x='ratings_count', y='average_rating' ,hover_data= ['title', 'authors','num_pages','text_reviews_count'],color="average_rating" )
# ----> 2 highestrated_books_fig.show(renderer="svg")
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in show(self, *args, **kwargs)
#    2853         import plotly.io as pio
#    2854
# -> 2855         return pio.show(self, *args, **kwargs)
#    2856
#    2857     def to_json(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\plotly\io\_renderers.py in show(fig, renderer, validate, **kwargs)
#     375
#     376     # Mimetype renderers
# --> 377     bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     378     if bundle:
# ...

# %%
#df for Top 10 Authors' Reading Counts and Average Rating
top10= books_data.sort_values(['ratings_count'], ascending = (False)).head(10)
top10
# Out:
#                                                    title  \
# 10336                            Twilight (Twilight  #1)
# 1697                 The Hobbit  or There and Back Again
# 1462                              The Catcher in the Rye
# 307                 Angels & Demons (Robert Langdon  #1)
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4415   Harry Potter and the Chamber of Secrets (Harry...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 23     The Fellowship of the Ring (The Lord of the Ri...
# 2114                                         Animal Farm
# 0      Harry Potter and the Half-Blood Prince (Harry ...
#
#                                        authors  average_rating language_code  \
# 10336                          Stephenie Meyer             3.6           eng
# 1697                            J.R.R. Tolkien             4.3           eng
# 1462                             J.D. Salinger             3.8           eng
# ...

# %%
top10_fig= px.bar(top10, y="average_rating", x="ratings_count" , orientation='h', hover_data= ['authors','title','publisher'], color='authors', title= "Top 10 Authors' Ratings Counts and Average Rating")
top10_fig.show(renderer="svg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-4287e43a501b> in <module>
#       1 top10_fig= px.bar(top10, y="average_rating", x="ratings_count" , orientation='h', hover_data= ['authors','title','publisher'], color='authors', title= "Top 10 Authors' Ratings Counts and Average Rating")
# ----> 2 top10_fig.show(renderer="svg")
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in show(self, *args, **kwargs)
#    2853         import plotly.io as pio
#    2854
# -> 2855         return pio.show(self, *args, **kwargs)
#    2856
#    2857     def to_json(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\plotly\io\_renderers.py in show(fig, renderer, validate, **kwargs)
#     375
#     376     # Mimetype renderers
# --> 377     bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     378     if bundle:
# ...

# %%
books_data['average_rating'].value_counts()

# %%
average_rating_val= books_data['average_rating'].value_counts().reset_index()
average_rating_val=average_rating_val.rename(columns={'index': 'average rating', 'average_rating':'value'})
figg = px.pie(average_rating_val, values='value', names='average rating' , color_discrete_sequence=px.colors.qualitative.Alphabet)
figg.update_traces(textposition='inside', textinfo='percent+label')
# Out:
# <div>
#
#
#             <div id="2fecb234-85c8-4873-a051-d64410ce185b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fecb234-85c8-4873-a051-d64410ce185b")) {
#                     Plotly.newPlot(
#                         '2fecb234-85c8-4873-a051-d64410ce185b',
# ...

# %%
book_language= books_data['language_code'].value_counts().reset_index()
book_language=book_language.rename(columns={'index': 'language', 'language_code':'value'})
figg = px.pie(book_language, values='value', names='language' , color_discrete_sequence=px.colors.qualitative.Safe)
figg.update_traces(textposition='inside', textinfo='percent+label')
# Out:
# <div>
#
#
#             <div id="509edc48-ae52-43dc-87dc-f66999e926a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("509edc48-ae52-43dc-87dc-f66999e926a0")) {
#                     Plotly.newPlot(
#                         '509edc48-ae52-43dc-87dc-f66999e926a0',
# ...

# %%
book_publisher= books_data['publisher'].value_counts().reset_index()
book_publisher=book_publisher.rename(columns={'index': 'Book Publisher', 'publisher':'value'})
book_publisher
book_publisher_fig = px.pie(book_publisher.head(50), values='value', names='Book Publisher' , color_discrete_sequence=px.colors.qualitative.Safe)
book_publisher_fig.update_traces(textposition='inside', textinfo='percent+label')
# Out:
# <div>
#
#
#             <div id="2eb538a5-c4bc-437f-ae57-7b7f955c5b26" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2eb538a5-c4bc-437f-ae57-7b7f955c5b26")) {
#                     Plotly.newPlot(
#                         '2eb538a5-c4bc-437f-ae57-7b7f955c5b26',
# ...

# %%
books_publish_year = books_data['publish_year'].value_counts().reset_index()
books_publish_year=books_publish_year.rename(columns={'publish_year': 'Value', 'index':'books publish year'})
books_publish_year
figs = px.bar(books_publish_year.head(50), x="books publish year", y="Value", color_discrete_sequence=px.colors.qualitative.Antique )
figs.show()
# Out:
# <div>
#
#
#             <div id="82c5452f-4111-4abf-8d56-8f4df3e40dd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("82c5452f-4111-4abf-8d56-8f4df3e40dd8")) {
#                     Plotly.newPlot(
#                         '82c5452f-4111-4abf-8d56-8f4df3e40dd8',
# ...

# %%
books_publishmonth = books_data['publish_month'].value_counts().reset_index()
books_publishmonth
# Out:
#    index  publish_month
# 0    Sep           1278
# 1    Oct           1212
# 2    Jan           1057
# 3    Apr            991
# 4    May            922
# 5    Jun            880
# 6    Aug            853
# 7    Nov            847
# 8    Mar            832
# 9    Jul            786
# 10   Feb            742
# 11   Dec            723

# %%
books_publishmonth = books_data['publish_month'].value_counts().reset_index()
books_publishmonth=books_publishmonth.rename(columns={'publish_month': 'Value', 'index':'books publish month'})
books_publishmonth
books_publishmonth_fig = px.bar(books_publishmonth, x="books publish month", y="Value", color='Value')
books_publishmonth_fig.show()
# Out:
# <div>
#
#
#             <div id="99341996-1041-4800-bc43-5d2b986c092b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("99341996-1041-4800-bc43-5d2b986c092b")) {
#                     Plotly.newPlot(
#                         '99341996-1041-4800-bc43-5d2b986c092b',
# ...

# %%
df_authors= books_data[['authors', 'average_rating', 'ratings_count','title','text_reviews_count','num_pages','publisher']]
df_authors
# Out:
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré             4.6
# 1                             J.K. Rowling/Mary GrandPré             4.5
# 2                                           J.K. Rowling             4.4
# 3                             J.K. Rowling/Mary GrandPré             4.6
# 4                             J.K. Rowling/Mary GrandPré             4.8
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...             4.1
# 11119                                William T. Vollmann             4.1
# 11120                                William T. Vollmann             4.0
# 11121                                William T. Vollmann             3.7
# 11122                                         Mark Twain             3.9
#
#        ratings_count                                              title  \
# ...

# %%
author_counts = df_authors['authors'].value_counts().reset_index()
author_counts=author_counts.rename(columns={'authors': 'Value', 'index':'author'})
author_counts=author_counts.head(100)
author_counts
# Out:
#                 author  Value
# 0         Stephen King     40
# 1       P.G. Wodehouse     40
# 2     Rumiko Takahashi     39
# 3     Orson Scott Card     35
# 4      Agatha Christie     33
# ..                 ...    ...
# 95        Jill Mansell     10
# 96  Colleen McCullough     10
# 97     Joseph Wambaugh     10
# 98    Raymond E. Feist     10
# 99    Richard A. Knaak     10
#
# [100 rows x 2 columns]

# %%
author_counts_fig = px.scatter(author_counts, x='author',size='Value', y='Value' ,color="author" )
author_counts_fig.show()
# Out:
# <div>
#
#
#             <div id="4135342d-a255-4ab2-ac16-9b4d661a38b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4135342d-a255-4ab2-ac16-9b4d661a38b4")) {
#                     Plotly.newPlot(
#                         '4135342d-a255-4ab2-ac16-9b4d661a38b4',
# ...

# %% [markdown]
# DATA VISUALIZATION FOR TOP 5 AUTHORS WHO HAVE THE MOST BOOKS ON  GOODREADS.

# %%
df_authors['authors'].value_counts().head(5)
# Out:
# Stephen King        40
# P.G. Wodehouse      40
# Rumiko Takahashi    39
# Orson Scott Card    35
# Agatha Christie     33
# Name: authors, dtype: int64

# %%
authors_grp=  df_authors.groupby(['authors'])

# %%
stephen_king= authors_grp.get_group('Stephen King')
stephen_king= stephen_king.sort_values(['average_rating'], ascending = (False))
stephen_king.head()
# Out:
#            authors  average_rating  ratings_count  \
# 1575  Stephen King             4.5          13137
# 9863  Stephen King             4.4         127648
# 8650  Stephen King             4.4            188
# 3150  Stephen King             4.4         207869
# 6016  Stephen King             4.3            362
#
#                                     title  text_reviews_count  num_pages  \
# 1575  Carrie / 'Salem's Lot / The Shining                  61       1096
# 9863                    Different Seasons                2080        560
# 8650                    Different Seasons                  24        560
# 3150                       The Green Mile                4570        592
# 6016   The Dark Tower (The Dark Tower #7)                  40        686
#
#                publisher
# 1575               Wings
# 9863        Warner Books
# 8650              Futura
# 3150      Penguin Signet
# 6016  Hodder & Stoughton

# %%
stephen_king_fig = px.histogram( stephen_king, stephen_king['average_rating'],  title="Stephen King' books Average Rating and Value Count",color_discrete_sequence=px.colors.qualitative.Antique)
stephen_king_fig.update_layout(bargap=0.9, xaxis_title_text = 'Average Rating',yaxis_title_text= 'Count')
stephen_king_fig.show()
# Out:
# <div>
#
#
#             <div id="41b47e08-5863-4bed-a73e-7157174fac05" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41b47e08-5863-4bed-a73e-7157174fac05")) {
#                     Plotly.newPlot(
#                         '41b47e08-5863-4bed-a73e-7157174fac05',
# ...

# %%
stephen_king_fig = px.bar(stephen_king, x="ratings_count", y="average_rating", orientation='h', hover_data= ['title','publisher'],color='ratings_count', title="Stephen King' books Average Rating and Ratings Count")
stephen_king_fig.show()
# Out:
# <div>
#
#
#             <div id="81cfb4f0-4f28-4509-81d2-fc72ea104f2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81cfb4f0-4f28-4509-81d2-fc72ea104f2c")) {
#                     Plotly.newPlot(
#                         '81cfb4f0-4f28-4509-81d2-fc72ea104f2c',
# ...

# %%
stephen_king_fig2= px.bar(stephen_king , y="average_rating", x="text_reviews_count", orientation='h', hover_data= ['title'], color='average_rating', title= 'Average Rating-Text Reviews Count graph')
stephen_king_fig2.show()
# Out:
# <div>
#
#
#             <div id="fb5ff43f-458d-4c63-9035-30194042a7b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fb5ff43f-458d-4c63-9035-30194042a7b4")) {
#                     Plotly.newPlot(
#                         'fb5ff43f-458d-4c63-9035-30194042a7b4',
# ...

# %%
stephen_king_fig2=px.pie(stephen_king,names='average_rating', values='ratings_count',title="Graph of Average Rating and  Percentage of Value Count",color_discrete_sequence=px.colors.qualitative.Antique) 
stephen_king_fig2.update_traces(textposition='inside', textinfo='percent+label')
stephen_king_fig2.show()
# Out:
# <div>
#
#
#             <div id="8ffa2390-2f14-415f-9381-050d0570424a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ffa2390-2f14-415f-9381-050d0570424a")) {
#                     Plotly.newPlot(
#                         '8ffa2390-2f14-415f-9381-050d0570424a',
# ...

# %%
stephen_king_mean= stephen_king.mean()
stephen_king_mean
df_stephen_king = pd.DataFrame(data=stephen_king_mean )
df_stephen_king=df_stephen_king.rename(columns={0:'stephen_king'}) 
df_stephen_king=df_stephen_king.T
df_stephen_king
# Out:
#               average_rating  ratings_count  text_reviews_count  num_pages
# stephen_king          3.9725       74640.85            1397.425    455.475

# %%
wodehouse= authors_grp.get_group('P.G. Wodehouse')

wodehouse= wodehouse.sort_values(['average_rating'],ascending = (False))
wodehouse.head()
# Out:
#              authors  average_rating  ratings_count  \
# 4548  P.G. Wodehouse             4.5           1872
# 4551  P.G. Wodehouse             4.4           3169
# 4980  P.G. Wodehouse             4.4           2651
# 3439  P.G. Wodehouse             4.3           6970
# 4555  P.G. Wodehouse             4.3           4616
#
#                                       title  text_reviews_count  num_pages  \
# 4548             The Most of P.G. Wodehouse                 106        701
# 4551  Life With Jeeves (Jeeves  #6  2  & 4)                 137        557
# 4980                      Life at Blandings                  47        608
# 3439  Stiff Upper Lip  Jeeves (Jeeves  #13)                 310        211
# 4555         The Mating Season (Jeeves  #9)                 287        272
#
#                publisher
# 4548    Simon & Schuster
# 4551       Penguin Books
# 4980       Penguin Books
# 3439  Everyman's Library
# 4555     Harry N. Abrams

# %%
wodehouse_fig = px.histogram( wodehouse, wodehouse['average_rating'],  title="P.G. Wodehouse' books Average Rating and Value Count",color_discrete_sequence=px.colors.qualitative.Antique)
wodehouse_fig.update_layout(bargap=0.9, xaxis_title_text = 'Average Rating',yaxis_title_text= 'Count')
wodehouse_fig.show()
# Out:
# <div>
#
#
#             <div id="f652fd03-1ea4-4b98-bf60-429802041a8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f652fd03-1ea4-4b98-bf60-429802041a8b")) {
#                     Plotly.newPlot(
#                         'f652fd03-1ea4-4b98-bf60-429802041a8b',
# ...

# %%
wodehouse_fig1 = px.bar(wodehouse, x="ratings_count", y="average_rating", orientation='h', hover_data= ['title'], color='average_rating', title="P.G. Wodehouse' books Average Rating and Ratings Count")
wodehouse_fig1.show()
# Out:
# <div>
#
#
#             <div id="cff55982-7b75-4498-8d1e-f24d6f1fd887" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cff55982-7b75-4498-8d1e-f24d6f1fd887")) {
#                     Plotly.newPlot(
#                         'cff55982-7b75-4498-8d1e-f24d6f1fd887',
# ...

# %%
wodehouse_fig2 = px.bar(wodehouse, y="average_rating", x="text_reviews_count", orientation='h', hover_data= ['title'],color='average_rating', title= 'Average Rating-Text Reviews Count graph')
wodehouse_fig2.show()
# Out:
# <div>
#
#
#             <div id="9c27b855-e08d-4eb3-9896-f5aef7866eb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c27b855-e08d-4eb3-9896-f5aef7866eb3")) {
#                     Plotly.newPlot(
#                         '9c27b855-e08d-4eb3-9896-f5aef7866eb3',
# ...

# %%
wodehouse_fig3=px.pie(wodehouse, names='average_rating', values='ratings_count',title="Graph of Average Rating and  Percentage of Value Count",color_discrete_sequence=px.colors.qualitative.Antique) 
wodehouse_fig3.update_traces(textposition='inside', textinfo='percent+label')
wodehouse_fig3.show()
# Out:
# <div>
#
#
#             <div id="e5f08928-9c75-4a0e-8502-0984c6717633" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e5f08928-9c75-4a0e-8502-0984c6717633")) {
#                     Plotly.newPlot(
#                         'e5f08928-9c75-4a0e-8502-0984c6717633',
# ...

# %%
wodehouse_mean= wodehouse.mean()
wodehouse_mean
df_wodehouse = pd.DataFrame(data=wodehouse_mean )
df_wodehouse=df_wodehouse.rename(columns={0:'P.G Wodehouse'}) 
df_wodehouse=df_wodehouse.T

df_wodehouse .head()
# Out:
#                average_rating  ratings_count  text_reviews_count  num_pages
# P.G Wodehouse          4.1475       2401.325             138.375    290.475

# %%
Rumiko_Takahashi= authors_grp.get_group('Rumiko Takahashi')
Rumiko_Takahashi= Rumiko_Takahashi.sort_values(['average_rating'], ascending= False)

Rumiko_Takahashi
# Out:
#                 authors  average_rating  ratings_count  \
# 6052   Rumiko Takahashi             4.4           5862
# 6279   Rumiko Takahashi             4.4            257
# 6067   Rumiko Takahashi             4.3             15
# 6068   Rumiko Takahashi             4.3             11
# 6066   Rumiko Takahashi             4.3             16
# 6280   Rumiko Takahashi             4.3            245
# 6281   Rumiko Takahashi             4.3            250
# 6284   Rumiko Takahashi             4.3            252
# 6078   Rumiko Takahashi             4.3             12
# 6077   Rumiko Takahashi             4.3             41
# 6076   Rumiko Takahashi             4.3             15
# 6072   Rumiko Takahashi             4.3             11
# 6070   Rumiko Takahashi             4.3             15
# 6069   Rumiko Takahashi             4.3             12
# 6075   Rumiko Takahashi             4.3             13
# 6273   Rumiko Takahashi             4.2          29058
# ...

# %%
Rumiko_Takahashi_fig = px.histogram( Rumiko_Takahashi, Rumiko_Takahashi['average_rating'],  title="Rumiko Takahashi' books Average Rating and Value Count",color_discrete_sequence=px.colors.qualitative.Antique)
Rumiko_Takahashi_fig.update_layout(bargap=0.9, xaxis_title_text = 'Average Rating',yaxis_title_text= 'Count')
Rumiko_Takahashi_fig.show()
# Out:
# <div>
#
#
#             <div id="179397d8-0754-4a0d-8681-46c281297717" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("179397d8-0754-4a0d-8681-46c281297717")) {
#                     Plotly.newPlot(
#                         '179397d8-0754-4a0d-8681-46c281297717',
# ...

# %%
Rumiko_Takahashi_fig1 = px.bar(Rumiko_Takahashi, x="ratings_count", y="average_rating", orientation='h', hover_data= ['title'], color='ratings_count', title="Rumiko Takahashi' books Average Rating and Ratings Count")
Rumiko_Takahashi_fig1.show()
# Out:
# <div>
#
#
#             <div id="70e1e344-faba-4eb9-9327-f2193c88c6a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("70e1e344-faba-4eb9-9327-f2193c88c6a5")) {
#                     Plotly.newPlot(
#                         '70e1e344-faba-4eb9-9327-f2193c88c6a5',
# ...

# %%
Rumiko_Takahashi_fig2 = px.bar(Rumiko_Takahashi, y="average_rating", x="text_reviews_count", orientation='h', hover_data= ['title'],color='average_rating', title= 'Average Rating-Text Reviews Count graph')
Rumiko_Takahashi_fig2.show()
# Out:
# <div>
#
#
#             <div id="1583bd3b-02c1-4242-b45d-56d60735b674" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1583bd3b-02c1-4242-b45d-56d60735b674")) {
#                     Plotly.newPlot(
#                         '1583bd3b-02c1-4242-b45d-56d60735b674',
# ...

# %%
Rumiko_Takahashi_fig3=px.pie(Rumiko_Takahashi,names='average_rating', values='ratings_count',title="Graph of Average Rating and  Percentage of Value Count",color_discrete_sequence=px.colors.qualitative.Antique) 
Rumiko_Takahashi_fig3.update_traces(textposition='inside', textinfo='percent+label')
Rumiko_Takahashi_fig3.show()
# Out:
# <div>
#
#
#             <div id="6925cabe-4ed9-437b-a316-cdb4fec3c8f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6925cabe-4ed9-437b-a316-cdb4fec3c8f7")) {
#                     Plotly.newPlot(
#                         '6925cabe-4ed9-437b-a316-cdb4fec3c8f7',
# ...

# %%
Rumiko_Takahashi_mean= Rumiko_Takahashi.mean()
Rumiko_Takahashi_mean
df_Rumiko_Takahashi = pd.DataFrame(data=Rumiko_Takahashi_mean )
df_Rumiko_Takahashi=df_Rumiko_Takahashi.rename(columns={0:'Rumiko Takahashi'}) 
df_Rumiko_Takahashi=df_Rumiko_Takahashi.T
df_Rumiko_Takahashi
# Out:
#                   average_rating  ratings_count  text_reviews_count  \
# Rumiko Takahashi        4.192308    1161.333333           15.076923
#
#                    num_pages
# Rumiko Takahashi  220.538462

# %%
Orson_Scott_Card= authors_grp.get_group('Orson Scott Card')
Orson_Scott_Card= Orson_Scott_Card.sort_values(by=['average_rating'], ascending= False)

Orson_Scott_Card.head()
# Out:
#                 authors  average_rating  ratings_count  \
# 2650   Orson Scott Card             4.5           1795
# 2591   Orson Scott Card             4.3         133114
# 2226   Orson Scott Card             4.1         190379
# 2651   Orson Scott Card             4.1            317
# 10000  Orson Scott Card             4.0          12940
#
#                                                    title  text_reviews_count  \
# 2650   Ender's Game Boxed Set: Ender's Game  Ender's ...                  60
# 2591              Ender's Shadow (The Shadow Series  #1)                4243
# 2226             Speaker for the Dead (Ender's Saga  #2)                6637
# 2651             Speaker for the Dead (Ender's Saga  #2)                  31
# 10000  Pastwatch: The Redemption of Christopher Columbus                 894
#
#        num_pages  publisher
# 2650        1296  Tor Books
# 2591         469  Starscape
# 2226         382  Tor Books
# 2651         432  Tor Books
# ...

# %%
Orson_Scott_Card_fig = px.histogram( Orson_Scott_Card, Orson_Scott_Card['average_rating'],  title="Orson Scott Card' books Average Rating and Value Count",color_discrete_sequence=px.colors.qualitative.Antique)
Orson_Scott_Card_fig.update_layout(bargap=0.9, xaxis_title_text = 'Average Rating',yaxis_title_text= 'Count')
Orson_Scott_Card_fig.show()
# Out:
# <div>
#
#
#             <div id="83f2e235-8e40-40b1-9b30-a8e9ed3825f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("83f2e235-8e40-40b1-9b30-a8e9ed3825f8")) {
#                     Plotly.newPlot(
#                         '83f2e235-8e40-40b1-9b30-a8e9ed3825f8',
# ...

# %%
osc = px.bar(Orson_Scott_Card, x="ratings_count", y="average_rating" , orientation='h',  hover_data= ['title'], color='average_rating',title="Orson Scott Card' books Average Rating and Ratings Count")
osc.show()
# Out:
# <div>
#
#
#             <div id="50bc28d9-daa9-4b81-9e37-80a54c21bd96" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("50bc28d9-daa9-4b81-9e37-80a54c21bd96")) {
#                     Plotly.newPlot(
#                         '50bc28d9-daa9-4b81-9e37-80a54c21bd96',
# ...

# %%
Orson_Scott_Card_fig = px.bar(Orson_Scott_Card, y="average_rating", x="text_reviews_count", orientation='h', hover_data= ['title'],color='average_rating', title= 'Average Rating-Text Reviews Count graph')
Orson_Scott_Card_fig.show()
# Out:
# <div>
#
#
#             <div id="a5187a06-6787-4b5a-a19c-bc96d59181a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a5187a06-6787-4b5a-a19c-bc96d59181a6")) {
#                     Plotly.newPlot(
#                         'a5187a06-6787-4b5a-a19c-bc96d59181a6',
# ...

# %%
Orson_Scott_Card_fig2=px.pie(Orson_Scott_Card, names='average_rating', values='ratings_count',title=" Graph of Average Rating and  Percentage of Value Count",color_discrete_sequence=px.colors.qualitative.Antique) #height=500,width=550)
Orson_Scott_Card_fig2.update_traces(textposition='inside', textinfo='percent+label')
Orson_Scott_Card_fig2.show()
# Out:
# <div>
#
#
#             <div id="5f7249dd-0b99-4fc9-b26f-228d1140ef1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5f7249dd-0b99-4fc9-b26f-228d1140ef1a")) {
#                     Plotly.newPlot(
#                         '5f7249dd-0b99-4fc9-b26f-228d1140ef1a',
# ...

# %%
Orson_Scott_Card_mean= Orson_Scott_Card.mean()
Orson_Scott_Card_mean
df_Orson_Scott_Card = pd.DataFrame(data=Orson_Scott_Card_mean )
df_Orson_Scott_Card=df_Orson_Scott_Card.rename(columns={0:'Orson Scott Card'}) 
df_Orson_Scott_Card=df_Orson_Scott_Card.T

df_Orson_Scott_Card
# Out:
#                   average_rating  ratings_count  text_reviews_count  \
# Orson Scott Card        3.777143   18758.685714               709.8
#
#                    num_pages
# Orson Scott Card  401.885714

# %%
Agatha_Christie= authors_grp.get_group('Agatha Christie')
Agatha_Christie= Agatha_Christie.sort_values(by=['average_rating'], ascending= False)
Agatha_Christie.head()
# Out:
#               authors  average_rating  ratings_count  \
# 8146  Agatha Christie             4.4            116
# 4518  Agatha Christie             4.3         625767
# 8151  Agatha Christie             4.3            138
# 4566  Agatha Christie             4.3           1865
# 4531  Agatha Christie             4.2         103149
#
#                                                   title  text_reviews_count  \
# 8146  Five Complete Miss Marple Novels: The Mirror C...                   6
# 4518                           And Then There Were None               18785
# 8151  Miss Marple Omnibus Vol. 3 (Murder at the Vica...                   5
# 4566    Hercule Poirot's Casebook (Hercule Poirot  #42)                  52
# 4531   The Murder of Roger Ackroyd (Hercule Poirot  #4)                5659
#
#       num_pages                         publisher
# 8146        650                      Avenel Books
# 4518        264                St. Martin's Press
# ...

# %%
Agatha_Christie_fig1 = px.histogram( Agatha_Christie, Agatha_Christie['average_rating'],  title="Agatha_Christie' books Average Rating and Value Count",color_discrete_sequence=px.colors.qualitative.Antique)
Agatha_Christie_fig1.update_layout(bargap=0.9, xaxis_title_text = 'Average Rating',yaxis_title_text= 'Count')
Agatha_Christie_fig1.show()
# Out:
# <div>
#
#
#             <div id="9779c469-7596-43a1-b71a-61e08990be03" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9779c469-7596-43a1-b71a-61e08990be03")) {
#                     Plotly.newPlot(
#                         '9779c469-7596-43a1-b71a-61e08990be03',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "average_rating=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "rgb(133, 92, 117)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [4.4, 4.3, 4.3, 4.3, 4.2, 4.2, 4.2, 4.2, 4.1, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 3.9, 3.9, 3.9, 3.9, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.7, 3.7], "xaxis": "x", "yaxis": "y"}],
# ...

# %%
Agatha_Christie_fig2= px.bar(Agatha_Christie, x="ratings_count", y="average_rating" , orientation='h', hover_data= ['title'], color='ratings_count',title="Agatha Christie' books Average Rating and Ratings Count")
Agatha_Christie_fig2.show()
# Out:
# <div>
#
#
#             <div id="9136aacf-94fe-4727-9a54-f910cc1eff15" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9136aacf-94fe-4727-9a54-f910cc1eff15")) {
#                     Plotly.newPlot(
#                         '9136aacf-94fe-4727-9a54-f910cc1eff15',
# ...

# %%
Agatha_Christie_fig3= px.bar(Agatha_Christie, y="average_rating", x="text_reviews_count", orientation='h', hover_data= ['title'],title= 'Average Rating-Text Reviews Count graph',color='average_rating')
Agatha_Christie_fig3.show()
# Out:
# <div>
#
#
#             <div id="32a4adec-4798-4a46-bc7a-99f14779e15e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("32a4adec-4798-4a46-bc7a-99f14779e15e")) {
#                     Plotly.newPlot(
#                         '32a4adec-4798-4a46-bc7a-99f14779e15e',
# ...

# %%
Agatha_Christie_fig3=px.pie(Agatha_Christie, names='average_rating', values='ratings_count',title='Graph of Average Rating and  Percentage of Value Count',color_discrete_sequence=px.colors.qualitative.Antique) #height=500,width=550)
Agatha_Christie_fig3.update_traces(textposition='inside', textinfo='percent+label')
Agatha_Christie_fig3.show()
# Out:
# <div>
#
#
#             <div id="8faaca9b-ebf5-482c-955b-ed05d79bdb6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8faaca9b-ebf5-482c-955b-ed05d79bdb6c")) {
#                     Plotly.newPlot(
#                         '8faaca9b-ebf5-482c-955b-ed05d79bdb6c',
# ...

# %%
Agatha_Christie_mean= Agatha_Christie.mean()
df_Agatha_Christie = pd.DataFrame(data=Agatha_Christie_mean )
df_Agatha_Christie=df_Agatha_Christie.rename(columns={0:'Agatha Christie'}) 
df_Agatha_Christie=df_Agatha_Christie.T
df_Agatha_Christie
# Out:
#                  average_rating  ratings_count  text_reviews_count   num_pages
# Agatha Christie        3.981818   48471.848485         1618.909091  319.878788

# %% [markdown]
# Data Visualization for  Mean Value of average_rating, ratings_count, text_reviews_count, and num_pages values.
# (TOP 5 AUTHORS'  WHO HAVE THE MOST BOOKS ON  GOODREADS)

# %%
top5_authors= (df_stephen_king,df_wodehouse,df_Rumiko_Takahashi,df_Orson_Scott_Card,df_Agatha_Christie)
df_mean_top5= pd.concat(top5_authors)
df_mean_top5
df_mean_top5=pd.concat(top5_authors,  keys=['Stephen King', 'P.G Wodehouse', 'Rumiko Takahashi', 'Orson Scott Card', 'Agatha Christie'],names=['author', None],).reset_index(level=0)
df_mean_top5
# Out:
#                             author  average_rating  ratings_count  \
# stephen_king          Stephen King        3.972500   74640.850000
# P.G Wodehouse        P.G Wodehouse        4.147500    2401.325000
# Rumiko Takahashi  Rumiko Takahashi        4.192308    1161.333333
# Orson Scott Card  Orson Scott Card        3.777143   18758.685714
# Agatha Christie    Agatha Christie        3.981818   48471.848485
#
#                   text_reviews_count   num_pages
# stephen_king             1397.425000  455.475000
# P.G Wodehouse             138.375000  290.475000
# Rumiko Takahashi           15.076923  220.538462
# Orson Scott Card          709.800000  401.885714
# Agatha Christie          1618.909091  319.878788

# %%
df_mean_top5_fig = px.bar(df_mean_top5, x="average_rating", y="ratings_count", hover_data= ['author'],color='author')
df_mean_top5_fig.show()
# Out:
# <div>
#
#
#             <div id="27ae3948-2423-4f6b-b5f8-30b741bb9294" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27ae3948-2423-4f6b-b5f8-30b741bb9294")) {
#                     Plotly.newPlot(
#                         '27ae3948-2423-4f6b-b5f8-30b741bb9294',
# ...

# %%
df_mean_top5_fig2 = px.bar(df_mean_top5, x="average_rating", y="text_reviews_count", hover_data= ['author'],color='author')
df_mean_top5_fig2.show()
# Out:
# <div>
#
#
#             <div id="6a217404-7658-4e7c-9673-e5d7784be9e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6a217404-7658-4e7c-9673-e5d7784be9e7")) {
#                     Plotly.newPlot(
#                         '6a217404-7658-4e7c-9673-e5d7784be9e7',
# ...

# %%
df_mean_top5_fig = px.bar(df_mean_top5, x="average_rating", y="num_pages", hover_data= ['author'],color='author')
df_mean_top5_fig.show()
# Out:
# <div>
#
#
#             <div id="2b334454-be7d-4045-a039-f70655ba02c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b334454-be7d-4045-a039-f70655ba02c7")) {
#                     Plotly.newPlot(
#                         '2b334454-be7d-4045-a039-f70655ba02c7',
# ...
